# %%
# !git clone --recursive https://github.com/ApurvaBhargava/pytorch-classification
# Out:
# Cloning into 'pytorch-classification'...
# remote: Enumerating objects: 320, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 320 (delta 5), reused 25 (delta 3), pack-reused 287
# Receiving objects: 100% (320/320), 70.77 MiB | 38.75 MiB/s, done.
# Resolving deltas: 100% (172/172), done.
# Submodule 'utils/progress' (https://github.com/verigak/progress.git) registered for path 'utils/progress'
# Cloning into '/content/pytorch-classification/utils/progress'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 306 (delta 19), reused 28 (delta 11), pack-reused 264
# Receiving objects: 100% (306/306), 662.72 KiB | 24.54 MiB/s, done.
# Resolving deltas: 100% (176/176), done.
# Submodule path 'utils/progress': checked out '715a2e130f14fa95c092c771813fb1c729dae333'

# %%
import os
os.chdir('pytorch-classification')
os.getcwd()
# Out:
# '/content/pytorch-classification'

# %%
# !python cifar.py -a densenet --dataset cifar100 --depth 100 --growthRate 12 --train-batch 64 --epochs 300 --schedule 150 225 --wd 1e-4 --gamma 0.1 --resume checkpoints/cifar100/densenet-bc-100-12/checkpoint209.pth.tar --checkpoint checkpoints/cifar100/densenet-bc-100-12
# Out:
# ==> Preparing dataset cifar100
# ...
# 169001984it [00:05, 29994180.86it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ==> creating model 'densenet'
#     Total params: 0.80M
# ==> Resuming from checkpoint..
#
# Epoch: [211 | 300] LR: 0.100000
# Processing |################################| (782/782) Data: 0.004s | Batch: 0.166s | Total: 0:02:09 | ETA: 0:00:01 | Loss: 0.0361 | top1:  99.4220 | top5:  100.0000
# cifar.py:307: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# !ls -la --time-style=full-iso blah /content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/
# Out:
# ls: cannot access 'blah': No such file or directory
# /content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/:
# total 93080
# drwxr-xr-x 2 root root    4096 2021-05-07 00:35:29.168132010 +0000 .
# drwxr-xr-x 3 root root    4096 2021-05-06 21:12:04.132319624 +0000 ..
# -rw-r--r-- 1 root root 6800303 2021-05-06 21:12:04.179321855 +0000 checkpoint0.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 21:12:04.226324085 +0000 checkpoint119.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 21:12:04.269326125 +0000 checkpoint149.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 21:12:04.311328118 +0000 checkpoint179.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 21:12:04.353330111 +0000 checkpoint19.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 21:12:04.396332152 +0000 checkpoint209.pth.tar
# -rw-r--r-- 1 root root 6800568 2021-05-06 22:20:17.933755007 +0000 checkpoint239.pth.tar
# ...

# %%
# !zip -r /content/pytorch-classification/dense_low.zip /content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/
# Out:
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/ (stored 0%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint19.pth.tar (deflated 10%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint29.pth.tar (deflated 10%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint209.pth.tar (deflated 10%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint119.pth.tar (deflated 9%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/log.txt (deflated 68%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint9.pth.tar (deflated 10%)
#   adding: content/pytorch-classification/checkpoints/cifar100/densenet-bc-100-12/checkpoint299.pth.tar (deflated 10%)
# ...

# %%
from google.colab import files
files.download("/content/pytorch-classification/dense_low.zip")
